# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # 3.3 Accessing Data
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) In this notebook you:<br>
#
# * Read data from a BLOB store
# * Read data in serial from JDBC
# * Read data in parallel from JDBC

# %%
# %run ../Includes/Classroom-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Data mounted to /mnt/davis ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) DBFS Mounts and S3
#
# Amazon Simple Storage Service (S3) is the backbone of Databricks workflows.  S3 offers data storage that easily scales to the demands of most data applications and, by colocating data with Spark clusters, Databricks quickly reads from and writes to S3 in a distributed manner.
#
# The Databricks File System, or DBFS, is a layer over S3 that allows you to [mount S3 buckets](https://docs.databricks.com/spark/latest/data-sources/aws/amazon-s3.html#mount-aws-s3), making them available to other users in your workspace and persisting the data after a cluster is shut down.
#
# In Azure Databricks, DBFS is backed by the Azure Blob Store. More documentation can be found [here](https://docs.azuredatabricks.net/spark/latest/data-sources/azure/azure-storage.html#mount-azure-blob-storage).

# %% [markdown]
# In the first lesson, you uploaded data using the Databricks user interface.  This can be done by clicking Data on the left-hand side of the screen.  Here we'll be mounting data.

# %% [markdown]
# Define your AWS credentials.  Below are defined read-only keys, the name of an AWS bucket, and the mount name we will be referring to in DBFS.
#
# For getting AWS keys, take a look at <a href="https://docs.aws.amazon.com/general/latest/gr/managing-aws-access-keys.html" target="_blank"> take a look at the AWS documentation

# %%
# %python
ACCESS_KEY = "AKIAJBRYNXGHORDHZB4A"
# Encode the Secret Key to remove any "/" characters
SECRET_KEY = "a0BzE1bSegfydr3%2FGE3LSPM6uIV5A4hOUfpH8aFF".replace("/", "%2F")
AWS_BUCKET_NAME = "davis-dsv1071/data/"
MOUNT_NAME = "/mnt/davis-tmp"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# -sandbox
#
# Now mount the bucket [using the template provided in the docs.](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html#mounting-an-s3-bucket)
#
# <img alt="Side Note" title="Side Note" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.05em; transform:rotate(15deg)" src="https://files.training.databricks.com/static/images/icon-note.webp"/> The code below includes error handling logic to handle the case where the mount is already mounted.

# %%
# %python
try:
  dbutils.fs.mount("s3a://{}:{}@{}".format(ACCESS_KEY, SECRET_KEY, AWS_BUCKET_NAME), MOUNT_NAME)
except:
  print("""{} already mounted. Unmount using `dbutils.fs.unmount("{}")` to unmount first""".format(MOUNT_NAME, MOUNT_NAME))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Next, explore the mount using `%fs ls` and the name of the mount.

# %%
# %fs ls /mnt/davis-tmp
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/davis-tmp/dataframes/</td><td>dataframes/</td><td>0</td></tr><tr><td>dbfs:/mnt/davis-tmp/fire-calls/</td><td>fire-calls/</td><td>0</td></tr><tr><td>dbfs:/mnt/davis-tmp/fire-incidents/</td><td>fire-incidents/</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# In practice, always secure your AWS credentials.  Do this by either maintaining a single notebook with restricted permissions that holds AWS keys, or delete the cells or notebooks that expose the keys. After a cell used to mount a bucket is run, you can access the data in this mount point in any notebook or any cluster in Databricks, and share the mount between colleagues.

# %%
# %fs mounts
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mountPoint</th><th>source</th><th>encryptionType</th></tr></thead><tbody><tr><td>/mnt/davis</td><td>s3a://davis-dsv1071/data</td><td></td></tr><tr><td>/databricks-datasets</td><td>databricks-datasets</td><td>sse-s3</td></tr><tr><td>/databricks/mlflow-tracking</td><td>databricks/mlflow-tracking</td><td>sse-s3</td></tr><tr><td>/databricks-results</td><td>databricks-results</td><td>sse-s3</td></tr><tr><td>/mnt/davis-tmp</td><td>s3a://davis-dsv1071/data/</td><td></td></tr><tr><td>/databricks/mlflow-registry</td><td>databricks/mlflow-registry</td><td>sse-s3</td></tr><tr><td>/</td><td>DatabricksRoot</td><td>sse-s3</td></tr></tbody></table></div>

# %% [markdown]
# You now have access to an unlimited store of data.  This is a read-only S3 bucket.  If you create and mount your own, you can write to it as well.

# %% [markdown]
# Now unmount the data.

# %%
# %python
dbutils.fs.unmount("/mnt/davis-tmp")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/davis-tmp has been unmounted.
# Out[4]: True</div>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Serial JDBC Reads
#
# Java Database Connectivity (JDBC) is an application programming interface (API) that defines database connections in Java environments.  Spark is written in Scala, which runs on the Java Virtual Machine (JVM).  This makes JDBC the preferred method for connecting to data whenever possible. Hadoop, Hive, and MySQL all run on Java and easily interface with Spark clusters.
#
# Databases are advanced technologies that benefit from decades of research and development. To leverage the inherent efficiencies of database engines, Spark uses an optimization called predicate push down.  **Predicate push down uses the database itself to handle certain parts of a query (the predicates).**  In mathematics and functional programming, a predicate is anything that returns a Boolean.  In SQL terms, this often refers to the `WHERE` clause.  Since the database is filtering data before it arrives on the Spark cluster, there's less data transfer across the network and fewer records for Spark to process.  Spark's Catalyst Optimizer includes predicate push down communicated through the JDBC API, making JDBC an ideal data source for Spark workloads.

# %% [markdown]
# Run the cell below to confirm you are using the right driver.

# %%
# %scala
Class.forName("org.postgresql.Driver")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res4: Class[_] = class org.postgresql.Driver
# </div>

# %% [markdown]
# First we need to create the JDBC String.

# %%
# %sql
DROP TABLE IF EXISTS twitterJDBC;

CREATE TABLE IF NOT EXISTS twitterJDBC
USING org.apache.spark.sql.jdbc
OPTIONS (
  driver "org.postgresql.Driver",
  url "jdbc:postgresql://server1.databricks.training:5432/training",
  user "readonly",
  password "readonly",
  dbtable "training.Account"
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# We now have a twitter table.

# %%
# %sql
SELECT * FROM twitterJDBC LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userID</th><th>screenName</th><th>location</th><th>friendsCount</th><th>followersCount</th><th>description</th><th>insertID</th><th>ETLID</th></tr></thead><tbody><tr><td>829933491664015360</td><td>zawakota0723</td><td>福岡市内</td><td>87</td><td>79</td><td>和白丘→水産 高３本田翼のファン
# 本田翼一推し歴4年優しく接してやってください｡ 気軽にフォローどうぞフォロバしますhttp://Instagram.com/fukuzawakota</td><td>343597397447</td><td>3153</td></tr><tr><td>3465776834</td><td>bcksojin86</td><td>null</td><td>52</td><td>10</td><td>null</td><td>343597397448</td><td>3153</td></tr><tr><td>450774034</td><td>REGULIA</td><td>null</td><td>811</td><td>79</td><td>20↑日本のマンガ文化・ゲームが大好きな中国人です－！簡単な日本語なら喋れる😃「ヘキカ_エン」の名義で本国のアニメ制作進行を務めています😝好きな物と仕事関連なことをつぶやく垢です❤よろしくお願いします😳</td><td>343597397449</td><td>3153</td></tr><tr><td>937766057472942080</td><td>forYou_Talal79</td><td>null</td><td>0</td><td>0</td><td>صدقه جاريه لك بالدنياء والأخره💙💙</td><td>343597397450</td><td>3153</td></tr><tr><td>933378720</td><td>hope_sherman</td><td>null</td><td>385</td><td>345</td><td>null</td><td>343597397451</td><td>3153</td></tr><tr><td>900846248030347265</td><td>mspyourselfrule</td><td>no where you need to know</td><td>274</td><td>104</td><td>[]Hello I'm on US server My user name is Yourselfrules[] (I also follow msp people back)[]Team Rose[]</td><td>343597397452</td><td>3153</td></tr><tr><td>913934030390796288</td><td>lhenzkie27</td><td>Tarlac City, Central Luzon</td><td>143</td><td>30</td><td>julianella fangirl...</td><td>343597397453</td><td>3153</td></tr><tr><td>804602734590595073</td><td>daddyjuice21</td><td>bompton</td><td>1209</td><td>615</td><td>you won’t ever come before brayson.</td><td>343597397454</td><td>3153</td></tr><tr><td>3240173659</td><td>YeemaxC</td><td>THAILAND</td><td>192</td><td>199</td><td>Support : NICHKHUN : 2PM :
# FC BAYERN : TWICE ❤</td><td>343597397455</td><td>3153</td></tr><tr><td>959211991649931264</td><td>drgddrf</td><td>null</td><td>1</td><td>1</td><td>null</td><td>343597397456</td><td>3153</td></tr></tbody></table></div>

# %% [markdown]
# Add a subquery to `dbtable`, which pushes the predicate to JDBC to process before transferring the data to your Spark cluster.

# %%
# %sql
DROP TABLE IF EXISTS twitterPhilippinesJDBC;

CREATE TABLE twitterPhilippinesJDBC
USING org.apache.spark.sql.jdbc
OPTIONS (
  driver "org.postgresql.Driver",
  url "jdbc:postgresql://server1.databricks.training:5432/training",
  user "readonly",
  password "readonly",
  dbtable "(SELECT * FROM training.Account WHERE location = 'Philippines') as subq"
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM twitterPhilippinesJDBC LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userID</th><th>screenName</th><th>location</th><th>friendsCount</th><th>followersCount</th><th>description</th><th>insertID</th><th>ETLID</th></tr></thead><tbody><tr><td>2414716389</td><td>miggyolilaa</td><td>Philippines</td><td>130</td><td>219</td><td>We are just souls lost between reality and dream 💫</td><td>343597397582</td><td>3153</td></tr><tr><td>829929175565819905</td><td>lesboooooy</td><td>Philippines</td><td>302</td><td>176</td><td>VIII•V•XV 💑 I•XXX•XVIII 💍
# // @McllGrcHp 🔥</td><td>369367202135</td><td>3153</td></tr><tr><td>444578604</td><td>KarrenTheGreat</td><td>Philippines</td><td>208</td><td>307</td><td>Wonder woman of my own version 💁</td><td>369367202827</td><td>3153</td></tr><tr><td>55088681</td><td>nikkiplanets</td><td>Philippines</td><td>438</td><td>158</td><td>null</td><td>369367202962</td><td>3153</td></tr><tr><td>955625563430969344</td><td>shokoy_</td><td>Philippines</td><td>232</td><td>48</td><td>*second account*</td><td>343597398952</td><td>3153</td></tr><tr><td>1479342410</td><td>jhaninacajefe</td><td>Philippines</td><td>236</td><td>279</td><td>null</td><td>369367204446</td><td>3153</td></tr><tr><td>144070866</td><td>bucaladenver</td><td>Philippines</td><td>76</td><td>92</td><td>Go suck my middle finger and I'll tell u wut!</td><td>352187335485</td><td>3153</td></tr><tr><td>40234887</td><td>tweetjoefred</td><td>Philippines</td><td>247</td><td>254</td><td>NVWS🖕🏼</td><td>352187335998</td><td>3153</td></tr><tr><td>376865035</td><td>lavpurple28</td><td>Philippines</td><td>275</td><td>948</td><td>NO ONE IS PERFECT!I'm a SOLID #KATHNIEL fan!💙 Don't follow me if you're a 🐸s or yung tga ibang LTs😝Di ka welcome d2👅#SongSongCouple❤️ #ParkBoGum😍 #YooSeungHo😍</td><td>369367204761</td><td>3153</td></tr><tr><td>1467205963</td><td>budithaeunicarn</td><td>Philippines</td><td>107</td><td>158</td><td>null</td><td>369367204831</td><td>3153</td></tr></tbody></table></div>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Parallel JDBC Reads

# %%
# %sql
SELECT min(userID) as minID, max(userID) as maxID from twitterJDBC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>minID</th><th>maxID</th></tr></thead><tbody><tr><td>509</td><td>959519629566672896</td></tr></tbody></table></div>

# %%
# %sql
DROP TABLE IF EXISTS twitterParallelJDBC;

CREATE TABLE IF NOT EXISTS twitterParallelJDBC
USING org.apache.spark.sql.jdbc
OPTIONS (
  driver "org.postgresql.Driver",
  url "jdbc:postgresql://server1.databricks.training:5432/training",
  user "readonly",
  password "readonly",
  dbtable "training.Account",
  partitionColumn '"userID"',
  lowerBound 2591,
  upperBound 951253910555168768,
  numPartitions 25
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * from twitterParallelJDBC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userID</th><th>screenName</th><th>location</th><th>friendsCount</th><th>followersCount</th><th>description</th><th>insertID</th><th>ETLID</th></tr></thead><tbody><tr><td>3465776834</td><td>bcksojin86</td><td>null</td><td>52</td><td>10</td><td>null</td><td>343597397448</td><td>3153</td></tr><tr><td>450774034</td><td>REGULIA</td><td>null</td><td>811</td><td>79</td><td>20↑日本のマンガ文化・ゲームが大好きな中国人です－！簡単な日本語なら喋れる😃「ヘキカ_エン」の名義で本国のアニメ制作進行を務めています😝好きな物と仕事関連なことをつぶやく垢です❤よろしくお願いします😳</td><td>343597397449</td><td>3153</td></tr><tr><td>933378720</td><td>hope_sherman</td><td>null</td><td>385</td><td>345</td><td>null</td><td>343597397451</td><td>3153</td></tr><tr><td>3240173659</td><td>YeemaxC</td><td>THAILAND</td><td>192</td><td>199</td><td>Support : NICHKHUN : 2PM :
td><td>null</td><td>343597397490</td><td>3153</td></tr><tr><td>428483629</td><td>valderramaangel</td><td>null</td><td>5002</td><td>4481</td><td>Amigo del orden y las sanas costumbres.</td><td>343597397491</td><td>3153</td></tr><tr><td>126304048</td><td>tachan117</td><td>Tokyo, JAPAN</td><td>489</td><td>248</td><td>HAYABUSAが欲しいスズ菌だけど…なぜか現在はカワサキのW800に浮気中の人。 「カワサキを讃えよ❗️ W8❗️W8 ❗️❗️」</td><td>343597397493</td><td>3153</td></tr><tr><td>2892155132</td><td>hes_hemmo</td><td>null</td><td>876</td><td>1377</td><td>album five track 5</td><td>343597397494</td><td>3153</td></tr><tr><td>190886650</td><td>Virgo1021</td><td>GA </td><td>1218</td><td>432</td><td>Mother, Wife, Daughter, Sister, Auntie, Friend</td><td>343597397495</td><td>3153</td></tr><tr><td>1897335180</td><td>tweetinsiren</td><td>null</td><td>894</td><td>192</td><td>hello i waited here for you creature comfort who'da thunk sittin drunk on a wagon to mexico #listenlonger👊👊</td><td>343597397496</td><td>3153</td></tr><tr><td>120509591</td><td>kabuzyouhou</td><td>中央区日本橋兜町</td><td>0</td><td>545</td><td>兜町相場師Ｔ・Ｋ氏の秘書兼アシスタント業務遂行
# 最新の株式銘柄を更新します！</td><td>343597397497</td><td>3153</td></tr><tr><td>367933825</td><td>lilian_odette</td><td>Welcome to Chile </td><td>1154</td><td>538</td><td>🎸rock, futbol,\UlC/ #Catlovers mi único vicio es DBZ🐉 ❤ leer ,estudio Ing.y trabajo todo me lo paga mi esfuerzo feminista #Antipiñera</td><td>343597397498</td><td>3153</td></tr><tr><td>3460060638</td><td>Ponzurasiiyo</td><td>火星のヨーロッパ首都ボルドー</td><td>108</td><td>123</td><td>🍭 透歌マチと彩崎アミトのキャラBotです👻 中のヒューマン( @NMzpan ）</td><td>343597397500</td><td>3153</td></tr><tr><td>4194244967</td><td>24steviep</td><td>Rochester, NY</td><td>865</td><td>290</td><td>Member of @katyperryforum and founder of Katycats Music List where I catalog every song @katyperry has ever done.</td><td>343597397501</td><td>3153</td></tr><tr><td>3386537091</td><td>xshadessofcooll</td><td>İzmir, Türkiye</td><td>882</td><td>1295</td><td>@Fenerbahce</td><td>343597397502</td><td>3153</td></tr><tr><td>3423415452</td><td>El_Beliceno</td><td>New York, USA</td><td>226</td><td>243</td><td>New Yorker | Mental Health Therapist| Lover | Fighter | Advocator | No hate, sexism, racism, homophobia, transphobia, heterophobia | L❤ve</td><td>343597397504</td><td>3153</td></tr><tr><td>36490577</td><td>ACfor_3</td><td>H-town NJ</td><td>876</td><td>800</td><td>avid tourist dodger. #Nets #Jets #Mets #devils

# %%
# %python
# %timeit sql("SELECT * from twitterJDBC").describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">28.4 s ± 2.15 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# </div>

# %%
# %python
# %timeit sql("SELECT * from twitterParallelJDBC").describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">31.6 s ± 1.62 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# </div>

# %% [markdown]
# For additional options [see the Spark docs.](https://spark.apache.org/docs/latest/sql-data-sources-jdbc.html)

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>

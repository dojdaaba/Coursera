# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # 3.6 Writing Data
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) In this notebook you:<br>
# * Employ the writing design pattern
# * Control partitions for database writes using REPARTITION and COALESCE hints

# %%
# %run ../Includes/Classroom-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Data mounted to /mnt/davis ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Writing From Spark<br>

# %% [markdown]
# -sandbox
# Writing to a database in Spark differs from other tools largely due to its distributed nature. There are a number of variables that can be tweaked to optimize performance, largely relating to how data is organized on the cluster. Partitions are the first step in understanding performant database connections.
#
# **A partition is a portion of your total data set,** which is divided into many of these portions so Spark can distribute your work across a cluster.
#
# The other concept needed to understand Spark's computation is a slot (also known as a core). **A slot/core is a resource available for the execution of computation in parallel.** In brief, a partition refers to the distribution of data while a slot refers to the distribution of computation.
#
# <div><img src="https://files.training.databricks.com/images/eLearning/ETL-Part-2/partitions-and-cores.png" style="height: 400px; margin: 20px"/></div>
#
# As a general rule of thumb, the number of partitions should be a multiple of the number of cores. For instance, with 5 partitions and 8 slots, 3 of the slots will be underutilized. With 9 partitions and 8 slots, a job will take twice as long as it waits for the extra partition to finish.

# %% [markdown]
# Import the dataset.

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW fireCallsCSV
USING CSV 
OPTIONS (
    path "/mnt/davis/fire-calls/fire-calls-truncated.csv",
    header "true",
    sep ":"
  )
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Switch to the Python API to run write commands.  You can do this `%python` and then run `sql(" <My Normal SQL Query> ")`

# %%
# %python
df = sql("SELECT * FROM fireCallsCSV")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Call Number</th><th>Unit ID</th><th>Incident Number</th><th>Call Type</th><th>Call Date</th><th>Watch Date</th><th>Received DtTm</th><th>Entry DtTm</th><th>Dispatch DtTm</th><th>Response DtTm</th><th>On Scene DtTm</th><th>Transport DtTm</th><th>Hospital DtTm</th><th>Call Final Disposition</th><th>Available DtTm</th><th>Address</th><th>City</th><th>Zipcode of Incident</th><th>Battalion</th><th>Station Area</th><th>Box</th><th>Original Priority</th><th>Priority</th><th>Final Priority</th><th>ALS Unit</th><th>Call Type Group</th><th>Number of Alarms</th><th>Unit Type</th><th>Unit sequence in call dispatch</th><th>Fire Prevention District</th><th>Supervisor District</th><th>Neighborhooods - Analysis Boundaries</th><th>Location</th><th>RowID</th></tr></thead><tbody><tr><td>001030118</td><td>E08</td><td>00030625</td><td>Medical Incident</td><td>04/12/2000</td><td>04/12/2000</td><td>04/12/2000 09:27:45 PM</td><td>04/12/2000 09:28:58 PM</td><td>04/12/2000 09:29:21 PM</td><td>04/12/2000 09:31:26 PM</td><td>04/12/2000 09:32:34 PM</td><td>null</td><td>null</td><td>Other</td><td>04/12/2000 09:45:28 PM</td><td>4TH ST/CHANNEL ST</td><td>SF</td><td>null</td><td>B03</td><td>08</td><td>2226</td><td>3</td><td>3</td><td>3</td><td>false</td><td>null</td><td>1</td><td>ENGINE</td><td>1</td><td>3</td><td>6</td><td>None</td><td>(37.7750268633971, -122.392346204303)</td><td>001030118-E08</td></tr><tr><td>001030122</td><td>M18</td><td>00030630</td><td>Medical Incident</td><td>04/12/2000</td><td>04/12/2000</td><td>04/12/2000 09:31:55 PM</td><td>04/12/2000 09:33:48 PM</td><td>04/12/2000 09:34:10 PM</td><td>04/12/2000 09:35:59 PM</td><td>04/12/2000 09:45:22 PM</td><td>null</td><td>null</td><td>Other</td><td>04/12/2000 09:49:52 PM</td><td>1800 Block of IRVING ST</td><td>SF</td><td>94122</td><td>B08</td><td>22</td><td>7424</td><td>1</td><td>1</td><td>2</td><td>false</td><td>null</td><td>1</td><td>MEDIC</td><td>1</td><td
tid-7317384288839858518-692d0c5a-6cf0-4ea3-b7ec-e236800248c0-1047-1-c000.csv&#39;, name=&#39;part-00007-tid-7317384288839858518-692d0c5a-6cf0-4ea3-b7ec-e236800248c0-1047-1-c000.csv&#39;, size=7589695)]</div>

# %% [markdown]
# Notice that it wrote a number of different parts, one for each partition.  Now let's get a sense for how to check how many partitions our data has, which once again is in Python.

# %%
# %python
df.rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: 8</div>

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Controlling Concurrency<br>

# %% [markdown]
# In the context of JDBC database writes, **the number of partitions determine the number of connections used to push data through the JDBC API.** There are two ways to control this parallelism:
#
# | Hint | Transformation Type | Use | Evenly distributes data across partitions? |
# | :----------------|:----------------|:----------------|:----------------|
# | `SELECT /*+ COALESCE(n) */`   | narrow (does not shuffle data) | reduce the number of partitions | no |
# | `SELECT /*+ REPARTITION(n) */`| wide (includes a shuffle operation) | increase the number of partitions | yes |

# %% [markdown]
# Create a new temporary view that coalesces all of our data to a single partition.  This can be done using a hint.

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW fireCallsCSV1p
  AS
SELECT /*+ COALESCE(1) */ * 
FROM fireCallsCSV
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Now check the number of partitions.

# %%
# %python
sql("SELECT * FROM fireCallsCSV1p").rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 1</div>

# %% [markdown]
# We now have a single partition.  What if we want more partitions?  Let's use a `REPARTITION` hint to evenly distribute our data across 8 partitions.

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW fireCallsCSV8p
  AS
SELECT /*+ REPARTITION(8) */ * 
FROM fireCallsCSV
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %python
sql("SELECT * FROM fireCallsCSV8p").rdd.getNumPartitions()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 8</div>

# %% [markdown]
# Now you can save the results.

# %%
# %python
sql("SELECT * FROM fireCallsCSV8p").write.mode("OVERWRITE").csv(username + "/fire-calls-repartitioned.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Click the arrow next to `Spark Jobs` under the following code cell in order to see a breakdown of the job you triggered. Click the next arrow to see a breakdown of the stages.
#
# When you repartitioned the DataFrame to 8 partitions, 8 stages were needed, one to write each partition of the data.

# %% [markdown]
# View the results.

# %%
# %python
dbutils.fs.ls(username + "/fire-calls-repartitioned.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/_SUCCESS&#39;, name=&#39;_SUCCESS&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/_committed_1265541773163778677&#39;, name=&#39;_committed_1265541773163778677&#39;, size=744),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/_started_1265541773163778677&#39;, name=&#39;_started_1265541773163778677&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/part-00000-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1056-1-c000.csv&#39;, name=&#39;part-00000-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1056-1-c000.csv&#39;, size=11161577),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/part-00001-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1057-1-c000.csv&#39;, name=&#39;part-00001-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1057-1-c000.csv&#39;, size=11150515),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/part-00002-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1058-1-c000.csv&#39;, name=&#39;part-00002-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1058-1-c000.csv&#39;, size=11151977),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/part-00003-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1059-1-c000.csv&#39;, name=&#39;part-00003-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1059-1-c000.csv&#39;, size=11146159),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/part-00004-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1060-1-c000.csv&#39;, name=&#39;part-00004-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1060-1-c000.csv&#39;, size=11148942),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/part-00005-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1061-1-c000.csv&#39;, name=&#39;part-00005-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1061-1-c000.csv&#39;, size=11155668),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/part-00006-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1062-1-c000.csv&#39;, name=&#39;part-00006-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1062-1-c000.csv&#39;, size=11150977),
#  FileInfo(path=&#39;dbfs:/panquistadore@gmail.com/fire-calls-repartitioned.csv/part-00007-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1063-1-c000.csv&#39;, name=&#39;part-00007-tid-1265541773163778677-cb37b0e5-84b8-43c2-968f-4498a8d6c4b8-1063-1-c000.csv&#39;, size=11156505)]</div>

# %% [markdown]
# ## Summary
# - Alter the number of concurrent writes using `SELECT /*+ COALESCE(n) */` or `SELECT /*+ REPARTITION(n) */`
# - Note that `coalesce` means something different in ANSI SQL (that is, to return the first non-null value)
# - Files like CSV and Parquet might look like single files, but Spark saves them as a folder of different parts

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>

# %% [markdown]
# d # Course: Distributed-Computing-with-Spark-SQL
# * Version 1.2.3
# * Built 2020-06-16 00:30:28 UTC
# * Git revision: d28e5131841c386130293a18e047eae3ed2fa999
#
# Copyright © 2020 Databricks, Inc.
